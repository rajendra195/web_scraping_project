# %%
import requests

# %%
url = "https://www.worldometers.info/gdp/nepal-gdp/"
html = requests.get(url).content

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
table = soup.find_all("table")[1]
title = table.find_all("th")
table_title = [item.text for item in title]
table_title
# Out:
# ['Year',
#  'GDP Nominal (Current USD) ',
#  'GDP Real  (Inflation adj.) ',
#  'GDP change',
#  'GDP per capita',
#  'Pop. change',
#  'Population']

# %%
import pandas as pd
df = pd.DataFrame(columns=table_title)
df
# Out:
# Empty DataFrame
# Columns: [Year, GDP Nominal (Current USD) , GDP Real  (Inflation adj.) , GDP change, GDP per capita, Pop. change, Population]
# Index: []

# %%
all_table_row = table.find_all("tr")
for row in all_table_row[1:]:
    row_data = row.find_all("td")
    data = [item.text for item in row_data]
    length = len(df)
    df.loc[length] = data

# %%
df
# Out:
#     Year GDP Nominal (Current USD)  GDP Real  (Inflation adj.)  GDP change  \
# 0   2022            $40,828,247,302             $33,084,084,559      5.61%
# 1   2021            $36,924,841,430             $31,325,711,843      4.84%
# 2   2020            $33,433,659,223             $29,880,069,382     -2.37%
# 3   2019            $34,186,180,695             $30,605,298,856      6.66%
# 4   2018            $33,111,525,183             $28,695,053,256      7.62%
# 5   2017            $28,971,588,881             $26,662,720,424      8.98%
# 6   2016            $24,524,109,485             $24,466,311,310      0.43%
# 7   2015            $24,360,801,338             $24,360,801,338      3.98%
# 8   2014            $22,731,612,827             $23,429,242,187      6.01%
# 9   2013            $22,162,205,046             $22,100,664,531      3.53%
# 10  2012            $21,703,100,747             $21,348,110,921      4.67%
# ...

# %%
data_csv = df.to_csv("data.csv", index=False)

# %%
data_to_db = df.to_records(index=False)

# %%
import sqlite3

# %%
con = sqlite3.connect("data.db")
cur = con.cursor()

# %%
query = """create table gdp(year varchar[20], nominal varchar[20], real varchar[20], change varchar[20], percapita varchar[20], popchange varchar[20], population varchar[20])"""

# %%
try:
    cur.execute(query)
except Exception as e:
    print(e)

# %%
query = """insert into gdp(year, nominal, real, change, percapita, popchange, population)
            values(?, ?, ?, ?, ?, ?, ?)"""
cur.executemany(query, data_to_db)

# %%
cur.execute("select * from gdp").fetchall()
# Out:
# [('2022',
#   '$40,828,247,302',
#   '$33,084,084,559',
#   '5.61%',
#   '$1,083',
#   '1.71 %',
#   '30,547,580'),
#  ('2021',
#   '$36,924,841,430',
#   '$31,325,711,843',
#   '4.84%',
#   '$1,043',
#   '2.34 %',
#   '30,034,989'),
#  ('2020',
#   '$33,433,659,223',
#   '$29,880,069,382',
#   '-2.37%',
#   '$1,018',
#   '1.79 %',
#   '29,348,627'),
#  ('2019',
#   '$34,186,180,695',
#   '$30,605,298,856',
#   '6.66%',
#   '$1,061',
#   '1.14 %',
#   '28,832,496'),
#  ('2018',
#   '$33,111,525,183',
#   '$28,695,053,256',
#   '7.62%',
#   '$1,007',
#   '1.15 %',
#   '28,506,712'),
#  ('2017',
#   '$28,971,588,881',
#   '$26,662,720,424',
#   '8.98%',
#   '$946',
#   '1.16 %',
#   '28,183,426'),
#  ('2016',
#   '$24,524,109,485',
#   '$24,466,311,310',
#   '0.43%',
#   '$878',
#   '0.91 %',
#   '27,861,186'),
#  ('2015',
#   '$24,360,801,338',
#   '$24,360,801,338',
#   '3.98%',
#   '$882',
#   '0.54 %',
#   '27,610,325'),
#  ('2014',
#   '$22,731,612,827',
#   '$23,429,242,187',
# ...

# %%
cur.execute("select population from gdp where year = '2000'").fetchall()
# Out:
# [('24,559,500',)]
