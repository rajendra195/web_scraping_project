# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

html = requests.get(url).content

soup = BeautifulSoup(html, "html.parser")

table = soup.find_all("table")[1]

# %%
title = [item.text.strip() for item in table.find_all("th")]

# %%
import pandas as pd
df = pd.DataFrame(columns=title)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
for row in table.find_all("tr")[1:]:
    table_data = row.find_all("td")
    data = [item.text.strip() for item in table_data]
    length = len(df)
    df.loc[length] = data

# %%
df
# Out:
#     Rank                      Name                      Industry  \
# 0    1\n                 Walmart\n                      Retail\n
# 1    2\n                  Amazon\n  Retail and cloud computing\n
# 2    3\n              ExxonMobil\n          Petroleum industry\n
# 3    4\n                   Apple\n        Electronics industry\n
# 4    5\n      UnitedHealth Group\n                  Healthcare\n
# ..   ...                       ...                           ...
# 295   96                  Best Buy                        Retail
# 296   97      Bristol-Myers Squibb       Pharmaceutical industry
# 297   98           United Airlines                       Airline
# 298   99  Thermo Fisher Scientific        Laboratory instruments
# 299  100                  Qualcomm                    Technology
#
#     Revenue (USD millions) Revenue growth    Employees  \
# 0                611,289\n         6.7%\n  2,100,000\n
# 1                513,983\n         9.4%\n  1,540,000\n
# 2                413,680\n        44.8%\n     62,000\n
# 3                394,328\n         7.8%\n    164,000\n
# 4                324,162\n        12.7%\n    400,000\n
# ..                     ...            ...          ...
# 295                 46,298          10.6%       71,100
# 296                 46,159           0.5%       34,300
# 297                 44,955          82.5%       92,795
# 298                 44,915          14.5%      130,000
# 299                 44,200          31.7%       51,000
#
#                 Headquarters
# 0    Bentonville, Arkansas\n
# 1      Seattle, Washington\n
# 2            Spring, Texas\n
# 3    Cupertino, California\n
# 4    Minnetonka, Minnesota\n
# ..                       ...
# 295     Richfield, Minnesota
# 296  New York City, New York
# 297        Chicago, Illinois
# 298   Waltham, Massachusetts
# 299    San Diego, California
#
# [300 rows x 7 columns]

# %%
df.to_csv("data.csv", index=False)
